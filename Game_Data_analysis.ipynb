# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

db_username = 'root'
db_password = 'root'
db_host = 'localhost' 
db_name = 'steam_data'

engine = create_engine(f'mysql+mysqlconnector://{db_username}:{db_password}@{db_host}/{db_name}')

# %%
query = 'select * from steamgen'
df = pd.read_sql(query, engine)

# %%
df['Tag1']=df['Tag1'].str.strip()
df['Tag2']=df['Tag2'].str.strip()
df['Price']=df['Price'].str.strip()

# %%
df.isnull().sum()
# Out:
# Title          744
# RAM           3329
# Size          4449
# Discount     34370
# Price         1928
# DLC              0
# Tag1           744
# Tag2           744
# Year           759
# ReviewNum     3052
# Image          744
# dtype: int64

# %%
df['Price'] = df['Price'].str.replace('Free To Play','0')
df['Price'] = df['Price'].str.replace('Free','0')
df['Price'] = df['Price'].str.replace(r'[₹,]','',regex=True).str.strip()

# %%
df['RAM'] = df['RAM'].str.extract(r'(\d+)')

# %%
df['Discount'] = df['Discount'].str.extract(r'(\d+)')
df['Discount'].fillna(0, inplace=True)

# %%
df = df[df['RAM'].isin(['1','2','3','4','8','6','12','16','1024','512'])]

# %%
df['Size'] = df['Size'].str.extract(r'(\d+\s*(?:GB|MB))')

# %%
df['Year'] = df['Year'].str.replace('Coming soon','2025')
df['Year'] = df['Year'].str.replace('Q4 2024','2024')

# %%
df = df[df['Year']!='To be announced']

# %%
df['Year'] = df['Year'].str.extract(r'(\d{4})')

# %%
df['Year'] = df['Year'].fillna('2019').astype('int')

# %%
df['Positivity_Percentage'] = df['ReviewNum'].str.extract(r'(\d+)%')
df['ReviewNum'] = df['ReviewNum'].str.extract(r'the\s([\d,]+)\suser')
df['ReviewNum'] = df['ReviewNum'].str.replace(',','')

# %%
df['Positivity_Percentage'] = pd.to_numeric(df['Positivity_Percentage'],errors='coerce')
df['ReviewNum'] = pd.to_numeric(df['ReviewNum'],errors='coerce')

# %%
df['Price'] = pd.to_numeric(df['Price'],errors='coerce')
df['Price'] = df['Price'].fillna(df['Price'].median())

# %%
df = df.drop_duplicates(keep='first').reset_index().drop(columns='index')

# %%
df['Size'] = df['Size'].str.replace(' GB','000')
df['Size'] = df['Size'].str.replace(' MB','')
df['Size'] = pd.to_numeric(df['Size'],errors='coerce')
df['Size'].fillna(df['Size'].mean(), inplace=True)

# %%
df['Discount'] = df['Discount'].astype('int')

# %%
df['RAM'] = df['RAM'].astype('float')
df['RAM'].apply(lambda x : x/1024 if x in [1024,512] else x).value_counts()
# Out:
# RAM
# 4.0     8843
# 2.0     6935
# 8.0     5374
# 1.0     4477
# 0.5     1983
# 6.0      762
# 16.0     562
# 3.0      282
# 12.0     145
# Name: count, dtype: int64

# %%
df[['Discount','Price']] = pd.DataFrame(df[['Discount','Price']].apply(lambda row: (100, row['Price']) if (row['Discount'] == 0 and row['Price'] == 0) else (row['Discount'], row['Price']), axis=1).tolist(),index=df.index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29363 entries, 0 to 29362
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  29363 non-null  object
#  1   RAM                    29363 non-null  float64
#  2   Size                   29363 non-null  float64
#  3   Discount               29363 non-null  float64
#  4   Price                  29363 non-null  float64
#  5   DLC                    29363 non-null  object
#  6   Tag1                   29363 non-null  object
#  7   Tag2                   29363 non-null  object
#  8   Year                   29363 non-null  int32
#  9   ReviewNum              21749 non-null  float64
#  10  Image                  29363 non-null  object
#  11  Positivity_Percentage  21749 non-null  float64
# dtypes: float64(6), int32(1), object(5)
# memory usage: 2.6+ MB

# %%
df.dropna(how='any',inplace=True)
df = df.loc[df['Price']<5000]

# %%
# Normalization function
def normalize_column(column, new_min, new_max):
    col_min = column.min()
    col_max = column.max()
    return new_min + (column - col_min) * (new_max - new_min) / (col_max - col_min)


df['Normalized'] = normalize_column(df['ReviewNum'],0,1)

# %%
def rev(col):
    if col>0.00005:
        return "Positive"
    elif col<0.000015:
        return "Negative"
    else:
        return "Mixed"
    
df['Reviews'] = df['Normalized'].apply(rev)

# %%
df['Total_revenue'] = df['Price'] * df['ReviewNum']
df.drop_duplicates(subset='Title',keep='first',inplace=True)

# %%
df.sample(20)
# Out:
#                                  Title  RAM          Size  Discount   Price  \
# 2073               孤独之旅 Lonely journey  4.0   1000.000000     100.0     0.0
# 23431        Roskis: A Boozy Beginning  2.0    200.000000     100.0     0.0
# 4487                    Rose and Cross  8.0   3000.000000       0.0   200.0
# 16635               Starship Inspector  1.0    250.000000       0.0   165.0
# 10728                DRAMAtical Murder  4.0   6000.000000       0.0   880.0
# 18669                       Blue Rider  2.0    650.000000       0.0   250.0
# 27218                  Chase Survivors  4.0    320.000000      80.0    31.0
# 18398          European Ship Simulator  4.0   2700.000000       0.0   565.0
# 1404        Monster Jam Steel Titans 2  4.0  20000.000000       0.0   909.0
# 10169                 Champions Online  2.0   4037.377791       0.0   250.0
# 4087                   Mechanic Heroes  8.0   3000.000000       0.0   400.0
# 20467                   Mahjong Nagomi  2.0   1000.000000       0.0   250.0
# 7901                          Sovranti  8.0   8000.000000     100.0     0.0
# 15009               CatBallGravityMaze  4.0     80.000000     100.0     0.0
# 10345                             Ruza  2.0    300.000000     100.0     0.0
# 453    LUNARiA -Virtualized Moonchild-  4.0   4000.000000       0.0   880.0
# 12167                   Sacred Citadel  2.0   4037.377791       0.0   369.0
# 2264               PIPE by BMX Streets  4.0    598.000000       0.0   349.0
# 19744                        EARTHLOCK  4.0   4000.000000       0.0  1365.0
# 7153        Serious Sam's Bogus Detour  2.0    500.000000       0.0   480.0
#
#        DLC              Tag1              Tag2  Year  ReviewNum  \
# 2073   Yes         Adventure        Platformer  2024       17.0
# 23431  Yes         Adventure               RPG  2021       21.0
# 4487    No         Adventure      First-Person  2024       28.0
# 16635  Yes          Strategy         Adventure  2021       44.0
# 10728   No            LGBTQ+    Sexual Content  2021     2721.0
# 18669  Yes            Action             Indie  2016       46.0
# 27218  Yes  Post-apocalyptic  Action Roguelike  2023       26.0
# 18398  Yes        Simulation        Open World  2016      572.0
# 1404   Yes            Racing            Sports  2021      261.0
# 10169   No      Free to Play         Superhero  2009     4093.0
# 4087   Yes      Online Co-Op       Local Co-Op  2023       36.0
# 20467  Yes            Casual        Board Game  2020      208.0
# 7901    No            Casual        Board Game  2023       13.0
# 15009   No            Puzzle         Difficult  2023       25.0
# 10345   No               RPG            Horror  2022      139.0
# 453     No         Adventure            Casual  2024       39.0
# 12167  Yes            Action       Beat 'em up  2013      587.0
# 2264    No            Sports        Simulation  2018     5347.0
# 19744  Yes               RPG         Adventure  2018      360.0
# 7153    No            Action             Indie  2017      371.0
#
#                                                    Image  \
# 2073   https://shared.akamai.steamstatic.com/store_it...
# 23431  https://shared.akamai.steamstatic.com/store_it...
# 4487   https://shared.akamai.steamstatic.com/store_it...
# 16635  https://shared.akamai.steamstatic.com/store_it...
# 10728  https://shared.akamai.steamstatic.com/store_it...
# 18669  https://shared.akamai.steamstatic.com/store_it...
# 27218  https://shared.akamai.steamstatic.com/store_it...
# 18398  https://shared.akamai.steamstatic.com/store_it...
# 1404   https://shared.akamai.steamstatic.com/store_it...
# 10169  https://shared.akamai.steamstatic.com/store_it...
# 4087   https://shared.akamai.steamstatic.com/store_it...
# 20467  https://shared.akamai.steamstatic.com/store_it...
# 7901   https://shared.akamai.steamstatic.com/store_it...
# 15009  https://shared.akamai.steamstatic.com/store_it...
# 10345  https://shared.akamai.steamstatic.com/store_it...
# 453    https://shared.akamai.steamstatic.com/store_it...
# 12167  https://shared.akamai.steamstatic.com/store_it...
# 2264   https://shared.akamai.steamstatic.com/store_it...
# 19744  https://shared.akamai.steamstatic.com/store_it...
# 7153   https://shared.akamai.steamstatic.com/store_it...
#
#        Positivity_Percentage  Normalized   Reviews  Total_revenue
# 2073                    35.0    0.000007  Negative            0.0
# 23431                   95.0    0.000012  Negative            0.0
# 4487                    82.0    0.000019     Mixed         5600.0
# 16635                   56.0    0.000036     Mixed         7260.0
# 10728                   96.0    0.002870  Positive      2394480.0
# 18669                   86.0    0.000038     Mixed        11500.0
# 27218                   80.0    0.000017     Mixed          806.0
# 18398                   41.0    0.000595  Positive       323180.0
# 1404                    78.0    0.000266  Positive       237249.0
# 10169                   71.0    0.004322  Positive      1023250.0
# 4087                    97.0    0.000028     Mixed        14400.0
# 20467                   81.0    0.000210  Positive        52000.0
# 7901                    69.0    0.000003  Negative            0.0
# 15009                   84.0    0.000016     Mixed            0.0
# 10345                   95.0    0.000137  Positive            0.0
# 453                    100.0    0.000031     Mixed        34320.0
# 12167                   72.0    0.000611  Positive       216603.0
# 2264                    92.0    0.005649  Positive      1866103.0
# 19744                   76.0    0.000370  Positive       491400.0
# 7153                    79.0    0.000382  Positive       178080.0

# %%
df.to_sql('steamout', con=engine, index=False, if_exists='replace')
# Out:
# -1
